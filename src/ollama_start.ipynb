# %%
user_content = '''
    ['序号', '名称', '规格', '单位', '数量', '厂家', '价格\n（万元）']
['1', '定子部分：', '定子部分：', '定子部分：', '定子部分：', '定子部分：', '']
['1', '差动式调节门', 'Q355', '套', '2', '江苏JTL', '66.5']
['1', '进气箱（含轴封）', 'Q355', '套', '2', '江苏JTL', '66.5']
['1', '机壳装配', 'Q355', '套', '1', '江苏JTL', '66.5']
'''

# %%
user_content = '''['序 号', '图纸、资料和技术文件名称', '份数']
['1', '装箱清单', '3']
['2', '产品合格证、质量检验证书、进口设备原产地证（若有）', '3']
['3', '装配图纸、原理图、接线图、系统图等', '3']
['4', '安装使用说明书、操作和维修手册', '3']'''

# %%
user_content = '''['序号', '货物名称', '规格型号', '单位', '数量', '单   价\n（万元RMB）', '总   价\n（万元RMB）', '交 货 期', '交货\n地点', '交货方式']
['1', '循环风机', 'Y5-2×48-14№32F\n2000kw  530000Nm3/h', '台', '1', '120', '120', '2021.4.15', '闽光钢铁项目现场', '汽车']
['2', '', '', '', '', '', '', '2021.4.15', '闽光钢铁项目现场', '汽车']
['3', '', '', '', '', '', '', '2021.4.15', '闽光钢铁项目现场', '汽车']
['4', '', '', '', '', '', '', '2021.4.15', '闽光钢铁项目现场', '汽车']
['总  计：', '总  计：', '总  计：', '总  计：', '总  计：', '总  计：', '120', '', '', '']
['注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。']'''

# %%
user_content = '''['项目名称', '项目名称', '项目名称', '', '', '', '', '', '工程类型', '工程类型', '', '']
['供方名称', '供方名称', '供方名称', '', '', '', '', '', '供方代码', '供方代码', '', '']
['合同号（订单号）', '合同号（订单号）', '合同号（订单号）', '', '', '', '', '', '箱  号', '箱  号', '', '']
['接存单位', '接存单位', '接存单位', '', '', '', '', '', '开箱日期', '开箱日期', '', '']
['设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '随  箱  文  件', '随  箱  文  件', '随  箱  文  件', '随  箱  文  件', '随  箱  文  件']
['设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '名 称', '份数', '页数', '页数', '接存单位份数']
['序号', '位号', '设备名称及规格\n（含专用工具及备品备件）', '设备名称及规格\n（含专用工具及备品备件）', '单\n位', '数 量', '数 量', '装箱单', '', '', '', '']
['序号', '位号', '设备名称及规格\n（含专用工具及备品备件）', '设备名称及规格\n（含专用工具及备品备件）', '单\n位', '应到数', '实到数', '合格证', '', '''

# %%
user_content = '''['序号', '货物名称', '规格型号', '单位', '数量', '单   价\n（万元RMB）', '总   价\n（万元RMB）', '交 货 期', '交货\n地点', '交货方式']
['1', '陶瓷泵泵头\nLC40/400TC', '流量：30m3/h，扬程:65m，比重1.3。泵体，泵盖材质：烧结陶瓷.叶轮材质WH20', '台', '2', '5', '10', '2023.10.23', '安阳钢铁项目现场', '汽车']
['2', '', '', '', '', '', '', '', '安阳钢铁项目现场', '']
['3', '', '', '', '', '', '', '', '安阳钢铁项目现场', '']
['4', '', '', '', '', '', '', '', '安阳钢铁项目现场', '']'''

# %%
user_content = '''['序号', '货物名称', '规格型号', '单位', '数量', '单   价\n（元RMB）', '总   价\n（元RMB）', '交 货 期', '交货\n地点', '交货方式']
['1', '渣浆泵泵头', '流量：20m3/h，扬程:30m，含固量10%-40%。材质：CR26.', '个', '1', '22600', '22600', '2024．12.15', '安阳钢铁', '汽运']
['2', '机械密封', 'LC-B40/300T', '套', '1', '2800', '2800', '2024．12.15', '安阳钢铁', '汽运']
['3', '叶轮', 'LC-B40/300T', '件', '1', '2650', '2650', '2024．12.15', '安阳钢铁', '汽运']
['4', '泵盖', 'LC-B40/300T', '件', '1', '2380', '2380', '2024．12.15', '安阳钢铁', '汽运']
['总  计', '总  计', '总  计', '总  计', '总  计', '总  计', '30430', '', '', '']
['注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。']
'''

# %%
from ollama import Client
client = Client(
  host='http://192.168.43.41:11434',
  headers={'x-some-header': 'some-value'}
)
response = client.chat(model='qwq:latest', 
                       options={
                           'temperature':0
                       },
                       messages=[
  {'role':'system', 'content': '''你是一位表格数据的识别判断专家，可以帮助分析提供的表格是否为设备表格，用户提供表格内容位于<table></table>标签中，识别要求如下：
   1、首先判断是否为设备表格：
      常见的设备表格的表头字段通常包含但是不局限有：名称或者设备名称，规格或者规格/材质，单位，数量，单价，总价，生产厂家等，
      如果主要字段基本符合设备表格的要求，那么可以判断**是**设备表格,按以下分析策略:
    1.1、需要逐个分析原始表头字段，标准化表头到指定的字段：设备名称、规格/材质、单位、数量、生产厂家、单价、总价；
      （分析的时候注意：一、没有出现价格字段，那么默认单价就是价格；二、标准化字段没有出现在原始表格中，将其结果设置为“ ”空然后原始表格对应提取字段索引设置为-1。)
    1.2、分析设备表格表头字段：   
      分析的时候请遵循以下步骤：
      1.2.1、逐个分析表头字段；
      1.2.2、分别整理每个字段；
      1.2.3、最后检查索引和对应原始表格字段和标准化后字段的名称映射正确。
    1.3、 按照要求生成XML结构：
      1.3.1、检查是否所有标准字段都被覆盖：
        设备名称：有|无
        规格/材质：有|无
        单位：有|无
        数量：有|无
        生产厂家：有|无
        单价：有|无
        总价：有|无       
        
        最后生成如下格式的XML：
        <fields>
            <field>
                <original>名称</original>
                <standard>设备名称</standard>
                <index>1</index>
            </field>
            <field>
                <original>规格/材质</original>
                <standard>规格/材质</standard>
                <index>2</index>
            </field>
            <field>
                <original>单位</original>
                <standard>单位</standard>
                <index>3</index>
            </field>
            <field>
                <original>数量</original>
                <standard>数量</standard>
                <index>4</index>
            </field>
            <field>
                <original>生产厂家</original>
                <standard>生产厂家</standard>
                <index>5</index>
            </field>
            <field>
                <original>单价</original>
                <standard>单价</standard>
                <index>6</index>
            </field>
            <field>
                <original>总价</original>
                <standard>总价</standard>
                <index>7</index>
            </field>
        </fields>
  
   2、如果用户提供的表格**不是**一份设备表格，请直接返回空xml，格式为<xml></xml>，不需要做任何的标准化字段提取。
   
   **注意：请严格遵守以上约定，先识别是否是设备表格，再根据对应的结果进行输出,最终的显示结果仅包含XML。**
   ''',},
  {
    'role': 'user',
    'content': f"<table>{user_content}</table>",
  },
])
print(response.message.content)
# Out:
# <think>
# 好的，我现在需要分析用户提供的表格是否为设备表格，并按照要求生成相应的XML。首先，我得仔细看看用户给的表格内容。
#
# 用户给出的表格数据看起来有点复杂，里面有很多合并单元格或者重复的标题行。比如第一行有“项目名称”重复三次，后面跟着空项，接着是“工程类型”等。可能这是多层表头的情况？不过先不管结构如何，我需要先判断是否符合设备表格的标准。
#
# 根据要求，设备表格通常包含设备名称、规格/材质、单位、数量、生产厂家、单价、总价这些字段。现在我要逐个检查提供的表头字段是否有这些内容。
#
# 首先看用户提供的表格中的各个列标题：
#
# 从第三行开始可能才是具体的字段？比如第七行有“序号”、“位号”、“设备名称及规格（含专用工具及备品备件）”重复两次，“单位”，“数 量”，“数 量”，“装箱单”等。第八行继续类似的内容，但有些变化。
#
# 可能需要先整理出所有表头字段。不过用户给出的表格数据似乎没有完全闭合的table标签，最后有个未闭合的</table>，但不管了，按现有内容分析。
#
# 重点看第七行和第八行：
#
# 第七行：
# 序号, 位号, 设备名称及规格（含专用工具及备品备件）, 同上重复一次, 单位, 数量, 数量, 装箱单, 空项，空项，空项
#
# 第八行：
# 序号, 位号, 设备名称及规格（含专用工具及备品备件），同上重复，单位，应到数，实到数，合格证等。
#
# 看起来主要字段可能包括“设备名称及规格”，这可以对应到标准化的“设备名称”和“规格/材质”。不过这里合并了两者，可能需要拆分。但根据规则，只要原始表头包含这些信息就算符合。例如，“设备名称及规格”可以映射到设备名称，而规格部分可能隐含在其中。
#
# 其他字段如单位、数量（应到数和实到数可能是数量的不同方面），但标准化的“数量”应该存在。生产厂家没有直接出现，单价和总价也没有提到。不过根据规则，如果没有价格相关字段，默认单价就是价格？或者这里可能没有价格信息？
#
# 另外，表头中还有位号、装箱单、合格证等，这些不属于设备表格的标准字段，但主要看是否满足核心字段。
#
# 现在检查标准化的七个字段是否存在：
#
# - 设备名称：有“设备名称及规格”，可以映射。
# - 规格/材质：可能包含在设备名称及规格里，所以存在。
# - 单位：有单位列。
# - 数量：有数量或应到数、实到数，但需要看是否有单独的数量字段。这里第七行的“数量”出现两次，可能是不同的，比如计划和实际？不过标准化只需要数量的话可能算有。
# - 生产厂家：没有看到对应的字段如生产厂家、供应商等，虽然前面有供方名称，但那是表头的一部分吗？
# - 单价：没有单价或价格相关字段。
# - 总价：也没有。
#
# 根据规则，如果主要字段基本符合设备表格的要求就算。这里设备名称、规格、单位、数量都有，但缺少生产厂家、单价和总价。不过可能用户认为只要有核心的几个就可以？比如设备名称、规格、单位、数量是必须的？
#
# 根据判断标准，只要主要字段存在即可视为设备表格。例如，即使没有价格或生产厂家，如果有设备名称、规格、单位、数量的话，可能还是算设备表。
#
# 但需要再仔细看规则中的第一条：常见的设备表格的表头字段通常包含但不限于那些字段，如果主要字段基本符合就算。这里的“主要”可能指设备名称、规格、数量这些核心项存在即可？
#
# 现在判断是否是设备表格：
#
# - 设备名称及规格存在（对应设备名称和规格/材质）
# - 单位存在
# - 数量存在
# 其他如生产厂家、单价总价没有，但可能不算必要。因此应该算作设备表格。
#
# 接下来需要生成XML映射每个原始列到标准化字段。
#
# 现在具体分析各列：
#
# 第七行的表头：
# 1. 序号 → 不相关
# 2. 位号 → 可能不对应标准字段
# 3. 设备名称及规格（含专用工具及备品备件）→ 映射到设备名称和规格/材质。可能需要将此列同时映射到这两个标准化字段，但根据规则可能分开处理？或者合并？
#    - 根据问题描述中的例子，比如如果有“设备名称及规格”可以拆分为设备名称和规格，但如果没有单独的规格列，则可能只映射到设备名称，而规格留空？不过这里用户可能希望将该字段同时覆盖两者。
#
# 4. 同上重复 → 可能是多列合并的情况，需要看具体结构。比如第三列可能占两列？
# 5. 单位 → 映射到单位
# 6. 数量（应到数、实到数）→ 这里有两个数量相关的列，但标准化只需要数量的话，可能选其中一个或合并？
#
# 第八行的表头：
# 1. 序号 → 同上
# 2. 位号 → 同样不相关
# 3. 设备名称及规格（重复）
# 4. 单位 → 同上
# 5. 应到数 → 可能对应数量？
# 6. 实到数 → 另一个数量，但标准化可能只需要其中一个。
# 7. 装箱单、合格证等其他字段。
#
# 现在需要确定每个原始列对应的标准化字段：
#
# 假设第七行的第三列是设备名称及规格，那么可以将其映射为：
# - 设备名称：该列
# - 规格/材质：同一列中的信息可能包含规格，但无法拆分，所以可能只能将整个列作为设备名称，而规格留空？或者认为该字段同时包含两者？
#
# 根据问题要求，只要原始表头存在这些内容即可。例如，“设备名称及规格”可以视为同时覆盖了设备名称和规格/材质的字段，因此这两个标准化字段都存在。
#
# 单位、数量（如“应到数”或“实到数”）存在。
#
# 生产厂家：没有对应的列。
# 单价和总价：也没有。
#
# 所以，在XML中需要将存在的映射出来：
#
# 原始列：
# - 设备名称及规格 → 设备名称 和 规格/材质
# - 单位 → 单位
# - 数量（比如“数量”或“应到数”）→ 数量
#
# 其他字段如位号、装箱单等不映射。
#
# 现在需要将每个原始列对应到标准化的字段：
#
# 例如，假设第三列是设备名称及规格，那么：
# <original_header>设备名称及规格（含专用工具及备品备件）</original_header>
# <mapped_to>设备名称, 规格/材质</mapped_to>
#
# 但XML可能需要分开处理每个映射。或者是否允许一个原始字段对应多个标准化字段？
#
# 根据问题中的示例，可能每个原始列只能映射到一个标准化字段。因此可能需要将该列同时作为设备名称和规格的来源？不过这可能不太准确。
#
# 另一种可能是，如果原始表头包含“设备名称及规格”，则将其视为设备名称，并认为规格信息在其中隐含，但标准化的规格/材质字段可能没有单独的列，所以只能映射到设备名称。而规格/材质可能无法找到对应的列？
#
# 这时候可能需要判断：是否必须所有七个字段都存在？或者只要主要几个存在即可。
#
# 根据问题中的规则，“如果主要字段基本符合设备表格的要求就算”，因此即使缺少生产厂家、单价和总价，只要有设备名称、规格、单位、数量的话，仍然视为设备表。所以可以继续生成XML映射存在的部分。
#
# 现在具体构建XML：
#
# 需要列出每个原始列头及其对应的标准化字段：
#
# 例如：
#
# 1. 序号 → 不映射
# 2. 位号 → 不映射
# 3. 设备名称及规格（含专用工具及备品备件）→ 设备名称 和 规格/材质？或者分开？
#    - 可能需要将该列同时作为设备名称和规格的来源，但XML可能要求每个原始列对应一个标准化字段。因此可能只能选择其中一个主要映射，比如设备名称，而规格留空？
#
# 这里可能存在歧义，但根据用户提供的例子，如果有类似“设备型号”这样的字段可以映射到规格/材质。
#
# 或者，将该列同时作为设备名称和规格的来源，例如：
#
# <mapping>
#   <original_header>设备名称及规格（含专用工具及备品备件）</original_header>
#   <mapped_to>设备名称, 规格/材质</mapped_to>
# </mapping>
#
# 但不确定是否允许这样。可能需要分开处理。
#
# 或者，将该列映射到设备名称，并认为规格信息包含在其中，而规格/材质字段没有单独的列：
#
# <mapping>
#   <original_header>设备名称及规格（含专用工具及备品备件）</original_header>
#   <mapped_to>设备名称</mapped_to>
# </mapping>
#
# 然后，规格/材质可能无法映射到任何原始列。
#
# 但根据问题要求，需要尽可能将所有标准化字段对应到原始列。因此可能需要这样处理：
#
# 假设该列同时包含设备名称和规格，则将其作为设备名称的来源，并认为规格信息在其中隐含，或者可能没有对应的列。
#
# 同样，单位、数量可以映射：
#
# <mapping>
#   <original_header>单位</original_header>
#   <mapped_to>单位</mapped_to>
# </mapping>
#
# <mapping>
#   <original_header>应到数</original_header>
#   <mapped_to>数量</mapped_to>
# </mapping>
#
# 或者选择“数量”列，如果存在的话。
#
# 现在需要确定原始表头中的具体字段名称。根据第七行的描述：
#
# 假设第七行的第三列是设备名称及规格，第四列可能也是同一合并单元格？例如，该列占用了两列？
#
# 这可能影响映射，但如果没有更多信息，只能基于给出的信息处理。
#
# 综上所述，最终的XML应包含以下映射：
#
# <mapping>
#   <original_header>设备名称及规格（含专用工具及备品备件）</original_header>
#   <mapped_to>设备名称, 规格/材质</mapped_to>
# </mapping>
#
# <mapping>
#   <original_header>单位</original_header>
#   <mapped_to>单位</mapped_to>
# </mapping>
#
# <mapping>
#   <original_header>应到数</original_header>
#   <mapped_to>数量</mapped_to>
# </mapping>
#
# 但可能需要将设备名称及规格拆分为两个映射项，或者只选择其中一个。
#
# 另一种可能是：
#
# <mapping>
#   <original_header>设备名称及规格（含专用工具及备品备件）</original_header>
#   <mapped_to>设备名称</mapped_to>
# </mapping>
#
# 然后，规格/材质可能没有对应的列，因此在XML中不映射？
#
# 但问题要求尽可能将所有标准化字段对应到原始列。所以可能需要这样处理：
#
# 假设该列同时包含设备名称和规格，则将其作为设备名称的来源，并认为规格信息在其中隐含，或者可能无法单独提取。
#
# 因此，在XML中只映射设备名称、单位、数量，而其他如规格/材质、生产厂家等没有对应的原始列。
#
# 最终生成的XML应包括所有存在的映射：
#
# <mapping>
#   <original_header>设备名称及规格（含专用工具及备品备件）</original_header>
#   <mapped_to>设备名称</mapped_to>
# </mapping>
#
# <mapping>
#   <original_header>单位</original_header>
#   <mapped_to>单位</mapped_to>
# </mapping>
#
# <mapping>
#   <original_header>应到数</original_header>
#   <mapped_to>数量</mapped_to>
# </mapping>
#
# 其他字段如规格/材质、生产厂家等没有对应的原始列，因此在XML中不出现。
#
# 但根据问题中的示例，可能需要将所有标准化字段列出，并指出哪些有映射：
#
# 例如，在XML的<mappings>部分只包含存在的映射，而未被映射的字段（如规格/材质）则不在其中。或者是否需要明确说明？
#
# 根据用户提供的例子，可能只需要列出存在的映射。
#
# 因此最终的XML结构如下：
