# %%
user_content = '''
    ['序号', '名称', '规格', '单位', '数量', '厂家', '价格\n（万元）']
['1', '定子部分：', '定子部分：', '定子部分：', '定子部分：', '定子部分：', '']
['1', '差动式调节门', 'Q355', '套', '2', '江苏JTL', '66.5']
['1', '进气箱（含轴封）', 'Q355', '套', '2', '江苏JTL', '66.5']
['1', '机壳装配', 'Q355', '套', '1', '江苏JTL', '66.5']
'''

# %%
user_content = '''['序 号', '图纸、资料和技术文件名称', '份数']
['1', '装箱清单', '3']
['2', '产品合格证、质量检验证书、进口设备原产地证（若有）', '3']
['3', '装配图纸、原理图、接线图、系统图等', '3']
['4', '安装使用说明书、操作和维修手册', '3']'''

# %%
user_content = '''['序号', '货物名称', '规格型号', '单位', '数量', '单   价\n（万元RMB）', '总   价\n（万元RMB）', '交 货 期', '交货\n地点', '交货方式']
['1', '循环风机', 'Y5-2×48-14№32F\n2000kw  530000Nm3/h', '台', '1', '120', '120', '2021.4.15', '闽光钢铁项目现场', '汽车']
['2', '', '', '', '', '', '', '2021.4.15', '闽光钢铁项目现场', '汽车']
['3', '', '', '', '', '', '', '2021.4.15', '闽光钢铁项目现场', '汽车']
['4', '', '', '', '', '', '', '2021.4.15', '闽光钢铁项目现场', '汽车']
['总  计：', '总  计：', '总  计：', '总  计：', '总  计：', '总  计：', '120', '', '', '']
['注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。']'''

# %%
user_content = '''['项目名称', '项目名称', '项目名称', '', '', '', '', '', '工程类型', '工程类型', '', '']
['供方名称', '供方名称', '供方名称', '', '', '', '', '', '供方代码', '供方代码', '', '']
['合同号（订单号）', '合同号（订单号）', '合同号（订单号）', '', '', '', '', '', '箱  号', '箱  号', '', '']
['接存单位', '接存单位', '接存单位', '', '', '', '', '', '开箱日期', '开箱日期', '', '']
['设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '随  箱  文  件', '随  箱  文  件', '随  箱  文  件', '随  箱  文  件', '随  箱  文  件']
['设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '设备包装检验、设备外观检查', '名 称', '份数', '页数', '页数', '接存单位份数']
['序号', '位号', '设备名称及规格\n（含专用工具及备品备件）', '设备名称及规格\n（含专用工具及备品备件）', '单\n位', '数 量', '数 量', '装箱单', '', '', '', '']
['序号', '位号', '设备名称及规格\n（含专用工具及备品备件）', '设备名称及规格\n（含专用工具及备品备件）', '单\n位', '应到数', '实到数', '合格证', '', '''

# %%
user_content = '''['序号', '货物名称', '规格型号', '单位', '数量', '单   价\n（万元RMB）', '总   价\n（万元RMB）', '交 货 期', '交货\n地点', '交货方式']
['1', '陶瓷泵泵头\nLC40/400TC', '流量：30m3/h，扬程:65m，比重1.3。泵体，泵盖材质：烧结陶瓷.叶轮材质WH20', '台', '2', '5', '10', '2023.10.23', '安阳钢铁项目现场', '汽车']
['2', '', '', '', '', '', '', '', '安阳钢铁项目现场', '']
['3', '', '', '', '', '', '', '', '安阳钢铁项目现场', '']
['4', '', '', '', '', '', '', '', '安阳钢铁项目现场', '']'''

# %%
user_content = '''['序号', '货物名称', '规格型号', '单位', '数量', '单   价\n（元RMB）', '总   价\n（元RMB）', '交 货 期', '交货\n地点', '交货方式']
['1', '渣浆泵泵头', '流量：20m3/h，扬程:30m，含固量10%-40%。材质：CR26.', '个', '1', '22600', '22600', '2024．12.15', '安阳钢铁', '汽运']
['2', '机械密封', 'LC-B40/300T', '套', '1', '2800', '2800', '2024．12.15', '安阳钢铁', '汽运']
['3', '叶轮', 'LC-B40/300T', '件', '1', '2650', '2650', '2024．12.15', '安阳钢铁', '汽运']
['4', '泵盖', 'LC-B40/300T', '件', '1', '2380', '2380', '2024．12.15', '安阳钢铁', '汽运']
['总  计', '总  计', '总  计', '总  计', '总  计', '总  计', '30430', '', '', '']
['注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。']
'''

# %%
system_prompt = '''
你是一位表格数据的识别判断专家，可以帮助分析提供的表格是否为设备\产品表格，用户提供表格内容位于<table></table>标签中，识别要求如下：
   1、首先判断是否为设备\产品表格：
      设备的表头一般出现在表格的前三行以内；
      常见的设备表格的表头字段通常包含但是不局限有：名称或者设备名称或产品，规格或者规格/材质或者型号，单位，数量，单价，总价，生产厂家等，
      如果主要字段基本符合设备表格的要求，名称或者设备名称是必需的，价格、单价、总价至少有一条是必需的，注意表头字段都是在同一行的。
      如果满足这些字段必须的条件，那么可以判断**是**设备表格,按以下分析策略:
    1.1、需要逐个分析原始表头字段，标准化表头到指定的字段：设备名称、规格/材质、单位、数量、生产厂家、单价、总价；
      （分析的时候注意：一、没有出现价格字段，那么默认单价就是价格；二、标准化字段没有出现在原始表格中，将其结果设置为“ ”空然后原始表格对应提取字段索引设置为-1。)
    1.2、分析设备表格表头字段：   
      分析的时候请遵循以下步骤：
      1.2.1、逐个分析表头字段：
        需要注意如果在分析价格字段的时候，将价格单位进行识别，常规是**元**或者**万元**（如果不属于二者其一，使用表格提供的原始单位数据），价格单位通常出现在价格字段之后，位于（）括号符号内；
      1.2.2、分别整理每个字段；
      1.2.3、最后检查索引和对应原始表格字段和标准化后字段的名称映射正确。
    1.3、 按照要求生成XML结构：
      1.3.1、检查是否所有标准字段都被覆盖：
        设备名称：有|无
        规格/材质：有|无
        单位：有|无
        数量：有|无
        生产厂家：有|无
        单价：有|无
        总价：有|无       
        
        最后生成如下格式的XML(start_row属性表示表头行索引，根据实际表头所在的行索引进行填写)，其中unit属性只有标准字段单价和总价才有：
        <fields start_row="0">
            <field original="名称" standard="设备名称" index="1"/>
            <field original="规格/材质" standard="规格/材质" index="2"/>
            <field original="单位" standard="单位" index="3"/>
            <field original="数量" standard="数量" index="4"/>
            <field original="生产厂家" standard="生产厂家" index="5"/>
            <field original="单价" standard="单价" unit="元" index="6"/>
            <field original="总价" standard="总价" unit="元" index="7"/>
        </fields>
  
   2、如果用户提供的表格**不是**一份设备表格，请直接返回空xml，格式为<xml></xml>，不需要做任何的标准化字段提取。
   
   **注意：请严格遵守以上约定，先识别是否是设备表格，再根据对应的结果进行输出,最终的显示结果仅包含XML。**
   
   在回答中请不要假设任何不属于用户提供的数据，并且不要虚拟数据，如实的根据用户提供的数据回答。
   
   以下是用户提供的表格数据：
'''

# %%
from os import system
from ollama import Client
client = Client(
  host='http://192.168.43.41:11434',
  headers={'x-some-header': 'some-value'}
)
response = client.chat(model='qwq:latest', 
                       options={
                           'temperature':0,
                           "num_ctx": 4096,
                       },
                       messages=[
  {'role':'system', 'content': system_prompt},
  {
    'role': 'user',
    'content': f"<table>{user_content}</table>"+"<think>\n",
  },
])
print(response.message.content)

input_text = response.message.content
# Out:
# <think>
# 好的，我现在需要分析用户提供的表格是否是设备或产品表格，并按照要求生成相应的XML结构。首先，我得仔细阅读用户的指令和提供的表格数据。
#
# 根据用户的要求，判断是否为设备/产品表格的关键在于表头字段是否包含必要的信息。首先检查表头所在的前三行。用户给出的表格第一行就是表头：['序号', '货物名称', '规格型号', '单位', '数量', '单   价（元RMB）', '总   价（元RMB）', '交 货 期', '交货地点', '交货方式']。这显然在前三行以内，符合设备表格的条件。
#
# 接下来需要确认是否包含必需字段：名称或设备名称、以及价格相关字段（单价、总价至少一个）。这里表头有“货物名称”，可以对应到“设备名称”；同时存在“单   价（元RMB）”和“总   价（元RMB）”，满足价格字段的要求。因此，这应该是一个设备表格。
#
# 接下来进行标准化映射：
#
# 1. 设备名称：对应的原始表头是“货物名称”，索引为1。
# 2. 规格/材质：“规格型号”对应，索引2。
# 3. 单位：直接匹配，索引3。
# 4. 数量：存在，索引4。
# 5. 生产厂家：原表头中没有这个字段，所以标准化后设为空，索引-1。
# 6. 单价：“单   价（元RMB）”对应，注意价格单位是“元”，索引5。需要处理括号内的单位信息。
# 7. 总价：“总   价（元RMB）”同样单位为元，索引6。
#
# 检查其他字段如交货期、地点和方式不属于标准化的字段，所以不需要映射。注意生产厂家在原始表头中没有出现，因此对应项留空。
#
# 最后生成XML结构时，start_row是0因为表头在第一行（索引从0开始）。每个field标签需要正确填写original、standard、index以及unit属性（仅单价和总价有）。
#
# 确认所有标准化字段是否覆盖：
# - 设备名称：有
# - 规格/材质：有
# - 单位：有
# - 数量：有
# - 生产厂家：无
# - 单价：有
# - 总价：有
#
# 因此，最终的XML应该包含这些映射，并正确设置unit属性为“元”。
# </think>
#
# <fields start_row="0">
#     <field original="货物名称" standard="设备名称" index="1"/>
#     <field original="规格型号" standard="规格/材质" index="2"/>
#     <field original="单位" standard="单位" index="3"/>
#     <field original="数量" standard="数量" index="4"/>
#     <field standard="生产厂家" original=" " index="-1"/>
#     <field original="单   价
# （元RMB）" standard="单价" unit="元" index="5"/>
#     <field original="总   价
# （元RMB）" standard="总价" unit="元" index="6"/>
# </fields>

# %%
import xml.etree.ElementTree as ET
from io import StringIO
import re

def extract_xml_to_dict(text):
    """
    从文本中提取XML结构并解析为字典列表，同时提取根节点的start_row属性。
    适应新的XML结构，其中field元素通过属性original、standard、index定义。
    
    参数:
        text (str): 包含XML结构的文本
        
    返回:
        tuple: (字段字典列表, start_row值) 如果解析失败返回 (None, None)
    """
    # 使用正则表达式提取<fields>...</fields>部分
    pattern = r'<fields.*?>.*?</fields>'
    matches = re.findall(pattern, text, re.DOTALL)
    
    if not matches:
        return None, None  # 如果没有找到XML结构，返回None, None
    
    xml_string = matches[-1]  # 取匹配列表中的最后一个元素
    
    # 解析XML
    try:
        root = ET.fromstring(xml_string)
        
        # 提取start_row属性，默认为None如果不存在
        start_row = root.get('start_row', None)
        
        # 解析field元素
        result = []
        for field in root.findall('field'):
            # 直接从属性中提取信息
            field_dict = {
                'original': field.get('original', ''),
                'standard': field.get('standard', ''),
                'unit': field.get('unit', ''),
                'index': field.get('index', '')
            }
            result.append(field_dict)
        
        return result, start_row
    
    except ET.ParseError:
        return None, None  # 如果XML格式错误，返回None, None

# %%
# 执行提取和转换
xml_map_result,start_row = extract_xml_to_dict(input_text)

# 打印结果
if xml_map_result:
    # import json
    # print(json.dumps(result, ensure_ascii=False, indent=2))
    print(xml_map_result,start_row)
else:
    print("无法提取或解析XML内容")
# Out:
# [{'original': '货物名称', 'standard': '设备名称', 'index': '1'}, {'original': '规格型号', 'standard': '规格/材质', 'index': '2'}, {'original': '单位', 'standard': '单位', 'index': '3'}, {'original': '数量', 'standard': '数量', 'index': '4'}, {'original': '', 'standard': '生产厂家', 'index': '-1'}, {'original': '单   价 （元RMB）', 'standard': '单价', 'index': '5'}, {'original': '总   价 （元RMB）', 'standard': '总价', 'index': '6'}] 0

# %%
def parse_table_to_objects(table, mapping_list, start_row=0):
    """
    根据映射列表从 python-docx 的 Table 对象中解析数据并转换为对象列表。
    未定义的表头字段将被聚合到 'other_column' 中。
    
    参数:
        table (docx.table.Table): python-docx 的表格对象
        mapping_list (list): 包含字典的列表，每个字典有 'original', 'standard', 'index' 键
        start_row (int): 开始解析的行号，默认为0
        
    返回:
        list: 解析后的对象列表，每个对象是一个字典
    """
    # 创建从原始标题到标准字段的映射
    header_mapping = {item['original']: item['standard'] for item in mapping_list}
    index_mapping = {item['original']: int(item['index']) for item in mapping_list}
    
    # 获取表头行（第一行）
    header_row = table.rows[0].cells
    headers = [cell.text.strip() for cell in header_row]
    
    # 验证表头是否与 mapping_list 中的 original 匹配，并找出未定义的表头
    undefined_headers = {}
    for idx, header in enumerate(headers):
        if header not in header_mapping and header != '':
            # print(f"警告: 表头 '{header}' 未在映射列表中定义，将被聚合到 other_column")
            undefined_headers[header] = idx
    
    # 解析数据行
    result = []
    start_row = int(start_row) + 1
    for row in table.rows[start_row:]:  # 从start_row+1行开始
        cells = [cell.text.strip() for cell in row.cells]
            
        # 创建对象
        obj = {}
        # 处理已定义的映射字段
        for original, standard in header_mapping.items():
            idx = index_mapping.get(original, -1)
            if idx >= 0 and idx < len(cells):  # 确保索引有效
                obj[standard] = cells[idx]
        
        # 处理未定义的字段，聚合到 other_column
        if undefined_headers:
            other_column = {}
            for header, idx in undefined_headers.items():
                if idx < len(cells):  # 确保索引有效
                    other_column[header] = cells[idx]
            if other_column:  # 只有当有内容时才添加 other_column
                obj['other_column'] = other_column
        
        result.append(obj)
    
    return result

# %%
file_path= "C:\\Lee\\files\\采购\\安阳钢铁集团有限责任公司综利公司烧结机头灰资源化处置项目（运营）\\04 渣浆泵备件采购合同.docx"

from docx import Document

table = Document(file_path).tables[0]

for row in table.rows:
    row_data = []
    # 遍历每一行的每个单元格
    for cell in row.cells:
        row_data.append(cell.text.strip())  # 获取单元格文本并去除多余空格
    print(row_data)  # 打印该行内容
# Out:
# ['序号', '货物名称', '规格型号', '单位', '数量', '单   价\n（元RMB）', '总   价\n（元RMB）', '交 货 期', '交货\n地点', '交货方式']
# ['1', '渣浆泵泵头', '流量：20m3/h，扬程:30m，含固量10%-40%。材质：CR26.', '个', '1', '22600', '22600', '2024．12.15', '安阳钢铁', '汽运']
# ['2', '机械密封', 'LC-B40/300T', '套', '1', '2800', '2800', '2024．12.15', '安阳钢铁', '汽运']
# ['3', '叶轮', 'LC-B40/300T', '件', '1', '2650', '2650', '2024．12.15', '安阳钢铁', '汽运']
# ['4', '泵盖', 'LC-B40/300T', '件', '1', '2380', '2380', '2024．12.15', '安阳钢铁', '汽运']
# ['总  计', '总  计', '总  计', '总  计', '总  计', '总  计', '30430', '', '', '']
# ['注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。', '注：1、本合同单价为含增值税、含运输费、包装费。']

# %%
parse_table_to_objects(table,xml_map_result,start_row)
# Out:
# 警告: 表头 '序号' 未在映射列表中定义，将被聚合到 other_column
# 警告: 表头 '单   价
# （元RMB）' 未在映射列表中定义，将被聚合到 other_column
# 警告: 表头 '总   价
# （元RMB）' 未在映射列表中定义，将被聚合到 other_column
# 警告: 表头 '交 货 期' 未在映射列表中定义，将被聚合到 other_column
# 警告: 表头 '交货
# 地点' 未在映射列表中定义，将被聚合到 other_column
# 警告: 表头 '交货方式' 未在映射列表中定义，将被聚合到 other_column
# [{'设备名称': '渣浆泵泵头',
#   '规格/材质': '流量：20m3/h，扬程:30m，含固量10%-40%。材质：CR26.',
#   '单位': '个',
#   '数量': '1',
#   '单价': '22600',
#   '总价': '22600',
#   'other_column': {'序号': '1',
#    '单   价\n（元RMB）': '22600',
#    '总   价\n（元RMB）': '22600',
#    '交 货 期': '2024．12.15',
#    '交货\n地点': '安阳钢铁',
#    '交货方式': '汽运'}},
#  {'设备名称': '机械密封',
#   '规格/材质': 'LC-B40/300T',
#   '单位': '套',
#   '数量': '1',
#   '单价': '2800',
#   '总价': '2800',
#   'other_column': {'序号': '2',
#    '单   价\n（元RMB）': '2800',
#    '总   价\n（元RMB）': '2800',
#    '交 货 期': '2024．12.15',
#    '交货\n地点': '安阳钢铁',
#    '交货方式': '汽运'}},
#  {'设备名称': '叶轮',
#   '规格/材质': 'LC-B40/300T',
#   '单位': '件',
#   '数量': '1',
#   '单价': '2650',
#   '总价': '2650',
#   'other_column': {'序号': '3',
#    '单   价\n（元RMB）': '2650',
#    '总   价\n（元RMB）': '2650',
#    '交 货 期': '2024．12.15',
#    '交货\n地点': '安阳钢铁',
#    '交货方式': '汽运'}},
#  {'设备名称': '泵盖',
#   '规格/材质': 'LC-B40/300T',
#   '单位': '件',
#   '数量': '1',
#   '单价': '2380',
#   '总价': '2380',
#   'other_column': {'序号': '4',
#    '单   价\n（元RMB）': '2380',
#    '总   价\n（元RMB）': '2380',
#    '交 货 期': '2024．12.15',
#    '交货\n地点': '安阳钢铁',
#    '交货方式': '汽运'}},
#  {'设备名称': '总  计',
#   '规格/材质': '总  计',
#   '单位': '总  计',
#   '数量': '总  计',
#   '单价': '总  计',
#   '总价': '30430',
#   'other_column': {'序号': '总  计',
#    '单   价\n（元RMB）': '总  计',
#    '总   价\n（元RMB）': '30430',
#    '交 货 期': '',
#    '交货\n地点': '',
#    '交货方式': ''}},
#  {'设备名称': '注：1、本合同单价为含增值税、含运输费、包装费。',
#   '规格/材质': '注：1、本合同单价为含增值税、含运输费、包装费。',
#   '单位': '注：1、本合同单价为含增值税、含运输费、包装费。',
#   '数量': '注：1、本合同单价为含增值税、含运输费、包装费。',
#   '单价': '注：1、本合同单价为含增值税、含运输费、包装费。',
#   '总价': '注：1、本合同单价为含增值税、含运输费、包装费。',
#   'other_column': {'序号': '注：1、本合同单价为含增值税、含运输费、包装费。',
#    '单   价\n（元RMB）': '注：1、本合同单价为含增值税、含运输费、包装费。',
#    '总   价\n（元RMB）': '注：1、本合同单价为含增值税、含运输费、包装费。',
#    '交 货 期': '注：1、本合同单价为含增值税、含运输费、包装费。',
#    '交货\n地点': '注：1、本合同单价为含增值税、含运输费、包装费。',
#    '交货方式': '注：1、本合同单价为含增值税、含运输费、包装费。'}}]
